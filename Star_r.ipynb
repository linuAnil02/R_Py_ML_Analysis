# %%
# install.packages("caret")
# install.packages("ROSE")
# install.packages("randomForest")
# install.packages("xgboost")
# install.packages("caTools")

# %%
library(dplyr)       
library(caret)
library(ROSE)
library(randomForest)
library(xgboost)
library(caTools)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: ggplot2
#
# Loading required package: lattice
#
# Loaded ROSE 0.0-4
#
#
# randomForest 4.7-1.1
#
# Type rfNews() to see new features/changes/bug fixes.
#
#
# Attaching package: ‘randomForest’
#
#
# The following object is masked from ‘package:ggplot2’:
#
#     margin
#
#
# The following object is masked from ‘package:dplyr’:
#
#     combine
#
#
#
# Attaching package: ‘xgboost’
#
#
# The following object is masked from ‘package:dplyr’:
#
#     slice

# %%
# Load the Dataset

df <- read.csv('star_classification.csv')
df
# Out:
#        obj_ID       alpha       delta      u        g        r        i
# 1      1.237661e+18 135.689107  32.4946318 23.87882 22.27530 20.39501 19.16573
# 2      1.237665e+18 144.826101  31.2741849 24.77759 22.83188 22.58444 21.16812
# 3      1.237661e+18 142.188790  35.5824442 25.26307 22.66389 20.60976 19.34857
# 4      1.237663e+18 338.741038  -0.4028276 22.13682 23.77656 21.61162 20.50454
# 5      1.237680e+18 345.282593  21.1838656 19.43718 17.58028 16.49747 15.97711
# 6      1.237680e+18 340.995121  20.5894763 23.48827 23.33776 21.32195 20.25615
# 7      1.237679e+18  23.234926  11.4181876 21.46973 21.17624 20.92829 20.60826
# 8      1.237679e+18   5.433176  12.0651860 22.24979 22.02172 20.34126 19.48794
# 9      1.237661e+18 200.290475  47.1994023 24.40286 22.35669 20.61032 19.46490
# 10     1.237671e+18  39.149691  28.1028416 21.74669 20.03493 19.17553 18.81823
# 11     1.237680e+18 328.092076  18.2203105 25.77163 22.52042 20.63884 19.78071
# 12     1.237662e+18 243.986637  25.7382804 23.76761 23.79969 20.98318 19.80745
# 13     1.237681e+18 345.801874  32.6728679 23.17274 20.14496 19.41948 19.22034
# 14     1.237679e+18 331.502030  10.0358020 20.82940 18.75091 17.51118 17.01631
# 15     1.237663e+18 344.984770  -0.3526158 23.20911 22.79291 22.08589 21.86282
# 16     1.237662e+18 244.824523  25.1545640 24.88680 22.13311 20.44728 19.49171
# 17     1.237679e+18 353.201522   3.0807959 24.54890 21.44267 20.95315 20.79360
# 18     1.237679e+18   1.494389   3.2917463 20.38562 20.40514 20.29996 20.05918
# 19     1.237679e+18  14.383135   3.2143262 21.82154 20.55730 19.94918 19.76057
# 20     1.237652e+18 167.131669  67.3399356 20.48292 18.67807 17.61680 17.11936
# 21     1.237652e+18 171.975425  67.7474501 22.13367 20.84772 18.96537 18.31696
# 22     1.237658e+18 144.785293  46.8264957 24.54793 22.33601 20.92259 19.87177
# 23     1.237658e+18 145.273037  46.9601338 25.44243 20.77028 19.66170 19.08481
# 24     1.237658e+18 145.883006  47.3004836 21.73992 21.53095 21.26763 21.36257
# 25     1.237662e+18 241.426267  27.2246949 18.88323 17.54229 17.01789 16.75376
# 26     1.237658e+18 132.922468   4.5218647 21.26110 20.50495 18.36379 23.17828
# 27     1.237658e+18 143.288018   5.5520522 25.98497 21.31456 19.61107 18.83178
# 28     1.237658e+18 140.600038   5.2657577 25.46577 22.40650 21.43408 20.26256
# 29     1.237663e+18 333.311511  -0.3761230 20.53324 18.84066 18.05369 17.60397
# 30     1.237663e+18 337.093435  -0.3117733 20.15491 18.37295 17.31276 16.82294
# [11] "cam_col"     "field_ID"    "spec_obj_ID" "class"       "redshift"
# [16] "plate"       "MJD"         "fiber_ID"

# %%
summary(df)
# Out:
#      obj_ID              alpha              delta               u
#  Min.   :1.238e+18   Min.   :  0.0055   Min.   :-18.785   Min.   :-9999.00
#  1st Qu.:1.238e+18   1st Qu.:127.5182   1st Qu.:  5.147   1st Qu.:   20.35
#  Median :1.238e+18   Median :180.9007   Median : 23.646   Median :   22.18
#  Mean   :1.238e+18   Mean   :177.6291   Mean   : 24.135   Mean   :   21.98
#  3rd Qu.:1.238e+18   3rd Qu.:233.8950   3rd Qu.: 39.902   3rd Qu.:   23.69
#  Max.   :1.238e+18   Max.   :359.9998   Max.   : 83.001   Max.   :   32.78
#        g                  r                i               z
#  Min.   :-9999.00   Min.   : 9.822   Min.   : 9.47   Min.   :-9999.00
#  1st Qu.:   18.96   1st Qu.:18.136   1st Qu.:17.73   1st Qu.:   17.46
#  Median :   21.10   Median :20.125   Median :19.41   Median :   19.00
#  Mean   :   20.53   Mean   :19.646   Mean   :19.08   Mean   :   18.67
#  3rd Qu.:   22.12   3rd Qu.:21.045   3rd Qu.:20.40   3rd Qu.:   19.92
#  Max.   :   31.60   Max.   :29.572   Max.   :32.14   Max.   :   29.38
#      run_ID        rerun_ID      cam_col         field_ID
#  Min.   : 109   Min.   :301   Min.   :1.000   Min.   : 11.0
#  1st Qu.:3187   1st Qu.:301   1st Qu.:2.000   1st Qu.: 82.0
#  Median :4188   Median :301   Median :4.000   Median :146.0
#  Mean   :4481   Mean   :301   Mean   :3.512   Mean   :186.1
#  3rd Qu.:5326   3rd Qu.:301   3rd Qu.:5.000   3rd Qu.:241.0
#  Max.   :8162   Max.   :301   Max.   :6.000   Max.   :989.0
#   spec_obj_ID           class              redshift             plate
#  Min.   :2.995e+17   Length:100000      Min.   :-0.009971   Min.   :  266
#  1st Qu.:2.844e+18   Class :character   1st Qu.: 0.054517   1st Qu.: 2526
#  Median :5.615e+18   Mode  :character   Median : 0.424173   Median : 4987
#  Mean   :5.784e+18                      Mean   : 0.576661   Mean   : 5137
#  3rd Qu.:8.332e+18                      3rd Qu.: 0.704154   3rd Qu.: 7400
#  Max.   :1.413e+19                      Max.   : 7.011245   Max.   :12547
#       MJD           fiber_ID
#  Min.   :51608   Min.   :   1.0
#  1st Qu.:54234   1st Qu.: 221.0
#  Median :55868   Median : 433.0
#  Mean   :55589   Mean   : 449.3
#  3rd Qu.:56777   3rd Qu.: 645.0
#  Max.   :58932   Max.   :1000.0

# %%
str(df)
# Out:
# 'data.frame':	100000 obs. of  18 variables:
#  $ obj_ID     : num  1.24e+18 1.24e+18 1.24e+18 1.24e+18 1.24e+18 ...
#  $ alpha      : num  136 145 142 339 345 ...
#  $ delta      : num  32.495 31.274 35.582 -0.403 21.184 ...
#  $ u          : num  23.9 24.8 25.3 22.1 19.4 ...
#  $ g          : num  22.3 22.8 22.7 23.8 17.6 ...
#  $ r          : num  20.4 22.6 20.6 21.6 16.5 ...
#  $ i          : num  19.2 21.2 19.3 20.5 16 ...
#  $ z          : num  18.8 21.6 18.9 19.3 15.5 ...
#  $ run_ID     : int  3606 4518 3606 4192 8102 8102 7773 7773 3716 5934 ...
#  $ rerun_ID   : int  301 301 301 301 301 301 301 301 301 301 ...
#  $ cam_col    : int  2 5 2 3 3 3 2 2 5 4 ...
#  $ field_ID   : int  79 119 120 214 137 110 462 346 108 122 ...
#  $ spec_obj_ID: num  6.54e+18 1.18e+19 5.15e+18 1.03e+19 6.89e+18 ...
#  $ class      : chr  "GALAXY" "GALAXY" "GALAXY" "GALAXY" ...
#  $ redshift   : num  0.635 0.779 0.644 0.932 0.116 ...
#  $ plate      : int  5812 10445 4576 9149 6121 5026 11069 6183 6625 2444 ...
#  $ MJD        : int  56354 58158 55592 58039 56187 55855 58456 56210 56386 54082 ...
#  $ fiber_ID   : int  171 427 299 775 842 741 113 15 719 232 ...

# %%
dim(df)
# Out:
# [1] 100000     18

# %%
rows_of_df <- nrow(df)
rows_of_df
# Out:
# [1] 100000

# %%
cols_of_df <- ncol(df)
cols_of_df
# Out:
# [1] 18

# %%
## 17 independent and 1 dependent variable

# %%
# Convert character columns to factor
df <- df %>%
  mutate_if(is.character, as.factor)

# %% [markdown]
# #### Remove irrelevant variables:

# %%
df <- df[, sapply(df, function(x) {
  if (is.factor(x)) {
    return(TRUE)  # Exclude factor variables
  } else {
    return(var(x) > 0)  # Calculate variance for non-factor variables
  }
})]

# %%
d<-dim(df)

# %%
# Print the number and proportion of irrelevant predictive/independent variables removed
rmvd <- cols_of_df - d[2]
prop <- rmvd / cols_of_df
print(paste("Number of Irrelevant Variables Removed:", rmvd))
print(paste("Proportion of Irrelevant Variables Removed:", prop))
# Out:
# [1] "Number of Irrelevant Variables Removed: 1"
# [1] "Proportion of Irrelevant Variables Removed: 0.0555555555555556"

# %%
# Print the number and proportion of irrelevant predictive/independent variables removed
rmvd <- cols_of_df - d[2]
prop <- rmvd / cols_of_df
print(paste("Number of Irrelevant Variables Removed:", rmvd))
print(paste("Proportion of Irrelevant Variables Removed:", prop))
# Out:
# [1] "Number of Irrelevant Variables Removed: 1"
# [1] "Proportion of Irrelevant Variables Removed: 0.0555555555555556"

# %%
summary(df)
# Out:
#      obj_ID              alpha              delta               u
#  Min.   :1.238e+18   Min.   :  0.0055   Min.   :-18.785   Min.   :-9999.00
#  1st Qu.:1.238e+18   1st Qu.:127.5182   1st Qu.:  5.147   1st Qu.:   20.35
#  Median :1.238e+18   Median :180.9007   Median : 23.646   Median :   22.18
#  Mean   :1.238e+18   Mean   :177.6291   Mean   : 24.135   Mean   :   21.98
#  3rd Qu.:1.238e+18   3rd Qu.:233.8950   3rd Qu.: 39.902   3rd Qu.:   23.69
#  Max.   :1.238e+18   Max.   :359.9998   Max.   : 83.001   Max.   :   32.78
#        g                  r                i               z
#  Min.   :-9999.00   Min.   : 9.822   Min.   : 9.47   Min.   :-9999.00
#  1st Qu.:   18.96   1st Qu.:18.136   1st Qu.:17.73   1st Qu.:   17.46
#  Median :   21.10   Median :20.125   Median :19.41   Median :   19.00
#  Mean   :   20.53   Mean   :19.646   Mean   :19.08   Mean   :   18.67
#  3rd Qu.:   22.12   3rd Qu.:21.045   3rd Qu.:20.40   3rd Qu.:   19.92
#  Max.   :   31.60   Max.   :29.572   Max.   :32.14   Max.   :   29.38
#      run_ID        cam_col         field_ID      spec_obj_ID
#  Min.   : 109   Min.   :1.000   Min.   : 11.0   Min.   :2.995e+17
#  1st Qu.:3187   1st Qu.:2.000   1st Qu.: 82.0   1st Qu.:2.844e+18
#  Median :4188   Median :4.000   Median :146.0   Median :5.615e+18
#  Mean   :4481   Mean   :3.512   Mean   :186.1   Mean   :5.784e+18
#  3rd Qu.:5326   3rd Qu.:5.000   3rd Qu.:241.0   3rd Qu.:8.332e+18
#  Max.   :8162   Max.   :6.000   Max.   :989.0   Max.   :1.413e+19
#     class          redshift             plate            MJD
#  GALAXY:59445   Min.   :-0.009971   Min.   :  266   Min.   :51608
#  QSO   :18961   1st Qu.: 0.054517   1st Qu.: 2526   1st Qu.:54234
#  STAR  :21594   Median : 0.424173   Median : 4987   Median :55868
#                 Mean   : 0.576661   Mean   : 5137   Mean   :55589
#                 3rd Qu.: 0.704154   3rd Qu.: 7400   3rd Qu.:56777
#                 Max.   : 7.011245   Max.   :12547   Max.   :58932
#     fiber_ID
#  Min.   :   1.0
#  1st Qu.: 221.0
#  Median : 433.0
#  Mean   : 449.3
#  3rd Qu.: 645.0
#  Max.   :1000.0

# %%
str(df)
# Out:
# 'data.frame':	100000 obs. of  17 variables:
#  $ obj_ID     : num  1.24e+18 1.24e+18 1.24e+18 1.24e+18 1.24e+18 ...
#  $ alpha      : num  136 145 142 339 345 ...
#  $ delta      : num  32.495 31.274 35.582 -0.403 21.184 ...
#  $ u          : num  23.9 24.8 25.3 22.1 19.4 ...
#  $ g          : num  22.3 22.8 22.7 23.8 17.6 ...
#  $ r          : num  20.4 22.6 20.6 21.6 16.5 ...
#  $ i          : num  19.2 21.2 19.3 20.5 16 ...
#  $ z          : num  18.8 21.6 18.9 19.3 15.5 ...
#  $ run_ID     : int  3606 4518 3606 4192 8102 8102 7773 7773 3716 5934 ...
#  $ cam_col    : int  2 5 2 3 3 3 2 2 5 4 ...
#  $ field_ID   : int  79 119 120 214 137 110 462 346 108 122 ...
#  $ spec_obj_ID: num  6.54e+18 1.18e+19 5.15e+18 1.03e+19 6.89e+18 ...
#  $ class      : Factor w/ 3 levels "GALAXY","QSO",..: 1 1 1 1 1 2 2 1 1 3 ...
#  $ redshift   : num  0.635 0.779 0.644 0.932 0.116 ...
#  $ plate      : int  5812 10445 4576 9149 6121 5026 11069 6183 6625 2444 ...
#  $ MJD        : int  56354 58158 55592 58039 56187 55855 58456 56210 56386 54082 ...
#  $ fiber_ID   : int  171 427 299 775 842 741 113 15 719 232 ...

# %% [markdown]
# #### Identify and remove out outliers:

# %%
par(mfrow=c(2,2))

columns_to_plot <- c('obj_ID','alpha','delta','u','g','r','i','z','run_ID','cam_col','field_ID','spec_obj_ID','class','redshift','plate','MJD','fiber_ID')

for (col in columns_to_plot) {
  boxplot(df[[col]], main = paste("Boxplot of", col))
}
# Out:
# Plot with title “Boxplot of u”
# Plot with title “Boxplot of z”
# Plot with title “Boxplot of spec_obj_ID”
# Plot with title “Boxplot of MJD”
# Plot with title “Boxplot of fiber_ID”

# %%
IQR <- function(x) {
  Q1 <- quantile(x, 0.25)
  Q3 <- quantile(x, 0.75)
  IQR <- Q3 - Q1
  lower_threshold <- Q1 - 1.5 * IQR
  upper_threshold <- Q3 + 1.5 * IQR
  outliers <- x < lower_threshold | x > upper_threshold
  return(outliers)
}

# %%
# assign numerical variables to nuim_vars
num_vars <- sapply(df, is.numeric)

# identify outliers i the dataframe
outlier <- sapply(df[, num_vars], IQR)

# sum of outliers
total <- sum(rowSums(outlier))
total
# Out:
# [1] 15186

# %%
new_df <- as.data.frame(lapply(df[, num_vars], IQR))

# %%
# Count the number of outliers filtered
fltrd <- sum(new_df != df[, num_vars])

# %%
# Calculate the proportion of outliers filtered
prop <- fltrd / (nrow(df) * length(num_vars))

# %%
# Output the results
cat("Number of outliers filtered:", total, "\n")
cat("Proportion of outliers filtered:", prop, "\n")
# Out:
# Number of outliers filtered: 15186
# Proportion of outliers filtered: 0.9409341

# %%
# assign numerical variables to nuim_vars
num_vars <- sapply(df, is.numeric)

# identify outliers i the dataframe
outlier <- sapply(df[, num_vars], IQR)

# sum of outliers
total <- sum(rowSums(outlier))
total
# Out:
# [1] 15186

# %%
new_df <- as.data.frame(lapply(df[, num_vars], IQR))

# %%
# Count the number of outliers filtered
fltrd <- sum(new_df != df[, num_vars])

# %%
# Calculate the proportion of outliers filtered
prop <- fltrd / (nrow(df) * length(num_vars))

# %%
# Output the results
cat("Number of outliers filtered:", total, "\n")
cat("Proportion of outliers filtered:", prop, "\n")
# Out:
# Number of outliers filtered: 15186
# Proportion of outliers filtered: 0.9409341

# %% [markdown]
# #### Romove duplicates

# %%
dimention <- dim(new_df)

# %%
new_df <- unique(df)

# %%
dimention_after <- dim(new_df)

# %%
removed <- dimention - dimention_after[1]
prop <- removed / dimention
print(paste("Number of Duplicate Records Removed:", removed))
print(paste("Proportion of Duplicate Records Removed:", prop))
# Out:
# [1] "Number of Duplicate Records Removed: 0"
# [2] "Number of Duplicate Records Removed: -99984"
# [1] "Proportion of Duplicate Records Removed: 0"
# [2] "Proportion of Duplicate Records Removed: -6249"

# %% [markdown]
# #### Remove Missing Values

# %%
colSums(is.na(new_df))
# Out:
#      obj_ID       alpha       delta           u           g           r
#           0           0           0           0           0           0
#           i           z      run_ID     cam_col    field_ID spec_obj_ID
#           0           0           0           0           0           0
#       class    redshift       plate         MJD    fiber_ID
#           0           0           0           0           0

# %% [markdown]
# #### Dimensionality reduction based on PCA

# %%
# numeric variables
num_cols <- sapply(new_df, is.numeric)

# %%
# PCA 
pca <- prcomp(new_df[, num_cols], scale. = TRUE)

# %%
# Summary of PCA results
summary(pca)
# Out:
# Importance of components:
#                           PC1    PC2    PC3     PC4     PC5     PC6     PC7
# Standard deviation     2.1661 1.7263 1.4380 1.12175 1.03976 0.95301 0.92080
# Proportion of Variance 0.2932 0.1863 0.1292 0.07865 0.06757 0.05676 0.05299
# Cumulative Proportion  0.2932 0.4795 0.6087 0.68737 0.75494 0.81171 0.86470
#                            PC8     PC9   PC10    PC11    PC12    PC13    PC14
# Standard deviation     0.89500 0.83875 0.7652 0.19864 0.18423 0.03282 0.01541
# Proportion of Variance 0.05006 0.04397 0.0366 0.00247 0.00212 0.00007 0.00001
# Cumulative Proportion  0.91476 0.95873 0.9953 0.99780 0.99992 0.99999 1.00000
#                             PC15      PC16
# Standard deviation     2.726e-08 5.873e-14
# Proportion of Variance 0.000e+00 0.000e+00
# Cumulative Proportion  1.000e+00 1.000e+00

# %%
# Extract the principal components
principal_components <- pca$x

# %%
# Optional: Scree plot
plot(pca)
# Out:
# Plot with title “pca”

# %%
# Assuming 'pca_result' contains the PCA-transformed features and 'new_df' is the original dataset
df_new <- cbind(new_df, principal_components)

# %% [markdown]
# #### Correlation matrix

# %%
# convert factor to numeric
factor_columns <- sapply(df_new, is.factor)
df_new[factor_columns] <- lapply(df_new[factor_columns], as.numeric)

# correlation matrix
cormat <- round(cor(df_new), 2)

# %%
get_upper_tri <- function(cormat)
    
{   
    cormat[lower.tri(cormat)]<- NA
    return(cormat)
}

# %%
upper_tri <- get_upper_tri(cormat)

# %%
# Melt the correlation matrix
library(reshape2)
cor_melt <- melt(upper_tri, na.rm = TRUE)

# %%
# Heatmap
library(ggplot2)

ggplot(data = cor_melt, aes(Var2, Var1, fill = value))+
 geom_tile(color = "white")+
 scale_fill_gradient2(low = "blue", high = "red", mid = "white", 
   midpoint = 0, limit = c(-1,1), space = "Lab", 
   name="Pearson\nCorrelation") +
  theme_minimal()+ 
 theme(axis.text.x = element_text(angle = 45, vjust = 1, 
    size = 12, hjust = 1))+
 coord_fixed()
# Out:
# plot without title

# %% [markdown]
# #### Normalise the data

# %%
# Normalize numerical variables using Min-Max scaling

df_new[, sapply(df_new, is.numeric)] <- 
                apply(df_new[, sapply(df_new, is.numeric)], 
                2, function(x) (x - min(x)) / (max(x) - min(x)))

# %%
print("Min-Max Scaled Data:")
print(head(df_new))
# Out:
# [1] "Min-Max Scaled Data:"
#      obj_ID     alpha     delta         u         g         r         i
# 1 0.4342034 0.3769048 0.5038025 0.9991126 0.9990702 0.5353444 0.4276646
# 2 0.5474962 0.4022858 0.4918121 0.9992022 0.9991256 0.6462028 0.5159863
# 3 0.4342035 0.3949598 0.5341388 0.9992505 0.9991089 0.5462180 0.4357293
# 4 0.5069848 0.9409469 0.1805998 0.9989389 0.9992198 0.5969456 0.4867170
# 5 0.9925028 0.9591182 0.3926793 0.9986698 0.9986021 0.3379985 0.2870206
# 6 0.9925028 0.9472084 0.3868397 0.9990736 0.9991761 0.5822786 0.4757610
#           z    run_ID cam_col   field_ID spec_obj_ID class   redshift     plate
# 1 0.9989440 0.4342481     0.2 0.06952965   0.4515852   0.0 0.09183086 0.4515919
# 2 0.9992253 0.5474978     0.8 0.11042945   0.8288330   0.0 0.11238889 0.8288413
# 3 0.9989594 0.4342481     0.2 0.11145194   0.3509462   0.0 0.09316979 0.3509486
# 4 0.9989895 0.5070160     0.4 0.20756646   0.7233129   0.0 0.13420985 0.7233124
# 5 0.9986200 0.9925494     0.4 0.12883436   0.4767589   0.0 0.01795891 0.4767527
# 6 0.9990190 0.9925494     0.4 0.10122699   0.3875963   0.5 0.20432782 0.3875906
#         MJD  fiber_ID       PC1       PC2       PC3       PC4       PC5
# 1 0.6480066 0.1701702 0.9090646 0.9989788 0.5609536 0.4363197 0.2182829
# 2 0.8943200 0.4264264 0.9549989 0.9985500 0.5512908 0.4327354 0.5507389
# 3 0.5439650 0.2982983 0.9031954 0.9991356 0.5619278 0.4551304 0.2836053
# 4 0.8780721 0.7747748 0.9454329 0.9985042 0.6006571 0.4042440 0.5548444
# 5 0.6252048 0.8418418 0.9007010 0.9985238 0.8560992 0.1314078 0.6106041
# 6 0.5798744 0.7407407 0.9307795 0.9987307 0.7992307 0.2711852 0.5628271
#         PC6       PC7       PC8       PC9      PC10      PC11      PC12
# 1 0.3129777 0.5989310 0.4074288 0.6911473 0.4910171 0.6563645 0.4141427
# 2 0.2826238 0.6523731 0.4982488 0.7363919 0.4943693 0.5810987 0.3875366
# 3 0.3399010 0.5427044 0.3859525 0.6660404 0.5262043 0.6519891 0.4120381
# 4 0.4261627 0.3333555 0.4632391 0.8213101 0.4038542 0.6151329 0.4110916
# 5 0.2758715 0.2890145 0.4520863 0.6592114 0.3966981 0.5988722 0.4231196
# 6 0.5030690 0.4045127 0.3995161 0.6021063 0.5236807 0.6246737 0.4119239
#        PC13      PC14      PC15      PC16
# 1 0.6217171 0.4921436 0.4411227 0.4567459
# 2 0.6357765 0.5531597 0.4219836 0.6076139
# 3 0.6069584 0.4993905 0.4379057 0.4053918
# 4 0.6465689 0.4340749 0.5054006 0.6865900
# 5 0.6235390 0.4960482 0.4436614 0.3709537
# 6 0.6331053 0.4645134 0.4433451 0.4584682

# %%
levels(df_new$class) <- c("GALAXY", "QSO", "STAR")

# %%
unique_values <- unique(df_new$class)
unique_values
# Out:
# [1] 0.0 0.5 1.0

# %%
dim(df_new)
str(df_new)
# Out:
# [1] 100000     33
# 'data.frame':	100000 obs. of  33 variables:
#  $ obj_ID     : num  0.434 0.547 0.434 0.507 0.993 ...
#  $ alpha      : num  0.377 0.402 0.395 0.941 0.959 ...
#  $ delta      : num  0.504 0.492 0.534 0.181 0.393 ...
#  $ u          : num  0.999 0.999 0.999 0.999 0.999 ...
#  $ g          : num  0.999 0.999 0.999 0.999 0.999 ...
#  $ r          : num  0.535 0.646 0.546 0.597 0.338 ...
#  $ i          : num  0.428 0.516 0.436 0.487 0.287 ...
#  $ z          : num  0.999 0.999 0.999 0.999 0.999 ...
#  $ run_ID     : num  0.434 0.547 0.434 0.507 0.993 ...
#  $ cam_col    : num  0.2 0.8 0.2 0.4 0.4 0.4 0.2 0.2 0.8 0.6 ...
#  $ field_ID   : num  0.0695 0.1104 0.1115 0.2076 0.1288 ...
#  $ spec_obj_ID: num  0.452 0.829 0.351 0.723 0.477 ...
#  $ class      : num  0 0 0 0 0 0.5 0.5 0 0 1 ...
#   ..- attr(*, "levels")= chr [1:3] "GALAXY" "QSO" "STAR"
#  $ redshift   : num  0.0918 0.1124 0.0932 0.1342 0.018 ...
#  $ plate      : num  0.452 0.829 0.351 0.723 0.477 ...
#  $ MJD        : num  0.648 0.894 0.544 0.878 0.625 ...
#  $ fiber_ID   : num  0.17 0.426 0.298 0.775 0.842 ...
#  $ PC1        : num  0.909 0.955 0.903 0.945 0.901 ...
#  $ PC2        : num  0.999 0.999 0.999 0.999 0.999 ...
#  $ PC3        : num  0.561 0.551 0.562 0.601 0.856 ...
#  $ PC4        : num  0.436 0.433 0.455 0.404 0.131 ...
#  $ PC5        : num  0.218 0.551 0.284 0.555 0.611 ...
#  $ PC6        : num  0.313 0.283 0.34 0.426 0.276 ...
#  $ PC7        : num  0.599 0.652 0.543 0.333 0.289 ...
#  $ PC8        : num  0.407 0.498 0.386 0.463 0.452 ...
#  $ PC9        : num  0.691 0.736 0.666 0.821 0.659 ...
#  $ PC10       : num  0.491 0.494 0.526 0.404 0.397 ...
#  $ PC11       : num  0.656 0.581 0.652 0.615 0.599 ...
#  $ PC12       : num  0.414 0.388 0.412 0.411 0.423 ...
#  $ PC13       : num  0.622 0.636 0.607 0.647 0.624 ...
#  $ PC14       : num  0.492 0.553 0.499 0.434 0.496 ...
#  $ PC15       : num  0.441 0.422 0.438 0.505 0.444 ...
#  $ PC16       : num  0.457 0.608 0.405 0.687 0.371 ...

# %%
write.csv(df_new, file = "star_r_preprocessed.csv", row.names = FALSE)

# %% [markdown]
# #### Train Test Split

# %%
# Split the dataset into training and testing sets
set.seed(123)  
trainIndex <- createDataPartition(df_new[["class"]], p = 0.7, list = FALSE)
train_data <- df_new[trainIndex, , drop = FALSE] 
test_data <- df_new[-trainIndex, , drop = FALSE]

# %%
train_class_distribution <- table(train_data$class)
test_class_distribution <- table(test_data$class)

print("Train Class Distribution:")
print(train_class_distribution)
print("Test Class Distribution:")
print(test_class_distribution)
# Out:
# [1] "Train Class Distribution:"
#
#     0   0.5     1
# 41625 13260 15116
# [1] "Test Class Distribution:"
#
#     0   0.5     1
# 17820  5701  6478

# %%
# Convert 'class' variable to factor
train_data$class <- factor(train_data$class)
test_data$class <- factor(test_data$class)

# %% [markdown]
# #### Random Forest

# %%
# Create a random forest model with classification
rf <- randomForest(class ~ ., 
                         data = train_data, 
                         ntree = 500, 
                         type = "classification")

# %%
# Print a summary of the model
print(rf)
# Out:
# Call:
#  randomForest(formula = class ~ ., data = train_data, ntree = 500,      type = "classification")
#                Type of random forest: classification
#                      Number of trees: 500
# No. of variables tried at each split: 5
#
#         OOB estimate of  error rate: 2.38%
# Confusion matrix:
#         0   0.5     1  class.error
# 0   40906   413   306 0.0172732733
# 0.5   935 12321     4 0.0708144796
# 1       8     0 15108 0.0005292405

# %%
# Make predictions on the test set
pred <- predict(rf, test_data)

# %%
# Evaluate the model
confusion_matrix <- table(pred, test_data$class)
accuracy <- sum(diag(confusion_matrix)) / sum(confusion_matrix)
print(confusion_matrix)
print(paste("Accuracy:", accuracy))
# Out:
#
# pred      0   0.5     1
#   0   17510   394     3
#   0.5   190  5307     0
#   1     120     0  6475
# [1] "Accuracy: 0.976432547751592"

# %%
conf_matrix <- matrix(c(17510, 394, 3, 190, 5307, 0, 120, 0, 6475), nrow = 3, byrow = TRUE,
                      dimnames = list(c("0", "0.5", "1"), c("0", "0.5", "1")))

binary_pred <- ifelse(as.numeric(row.names(conf_matrix)) >= 0.5, 1, 0)

precision <- diag(conf_matrix) / rowSums(conf_matrix)
recall <- diag(conf_matrix) / colSums(conf_matrix)
f1_score <- 2 * precision * recall / (precision + recall)

cat("F1 Score class 0:", f1_score[1], "\n")
cat("F1 Score class 0.5:", f1_score[2], "\n")
cat("F1 Score class 1:", f1_score[3], "\n")
# Out:
# F1 Score for class 0: 0.980211
# F1 Score for class 0.5: 0.9478478
# F1 Score for class 1: 0.9905913

# %%
f1_scores <- c(0.980211, 0.9478478, 0.9905913)

avg <- mean(f1_scores)

cat("Mean F1 Score:", avg, "\n")
# Out:
# Mean F1 Score: 0.9728834

# %% [markdown]
# #### Train Test Split

# %%
set.seed(123)

# %%
# Set the ratio
split <- sample.split(df_new$class, SplitRatio = 0.7) 

# train set
train_data <- subset(df_new, split == TRUE)

# test set
test_data <- subset(df_new, split == FALSE)

# %%
# one-hot encoding
train_data_encoded <- model.matrix(~ . - 1, data = train_data[, -which(names(train_data) == "class")])
test_data_encoded <- model.matrix(~ . - 1, data = test_data[, -which(names(test_data) == "class")])

# %% [markdown]
# #### Gradient Boosting

# %%
xgb <- xgboost(
  data = as.matrix(train_data_encoded),
  label = train_data$class,
  nrounds = 100,
  objective = "multi:softmax",
  num_class = length(unique(train_data$class))) # Adjusted to the number of unique classes
# Out:
# [1]	train-mlogloss:0.777112
# [2]	train-mlogloss:0.593702
# [3]	train-mlogloss:0.475568
# [4]	train-mlogloss:0.395451
# [5]	train-mlogloss:0.339400
# [6]	train-mlogloss:0.299416
# [7]	train-mlogloss:0.270951
# [8]	train-mlogloss:0.250268
# [9]	train-mlogloss:0.235353
# [10]	train-mlogloss:0.224438
# [11]	train-mlogloss:0.216600
# [12]	train-mlogloss:0.210868
# [13]	train-mlogloss:0.206682
# [14]	train-mlogloss:0.203680
# [15]	train-mlogloss:0.201427
# [16]	train-mlogloss:0.199853
# [17]	train-mlogloss:0.198685
# [18]	train-mlogloss:0.197957
# [19]	train-mlogloss:0.197307
# [20]	train-mlogloss:0.196837
# [21]	train-mlogloss:0.196526
# [22]	train-mlogloss:0.196311
# [23]	train-mlogloss:0.196137
# [24]	train-mlogloss:0.196080
# [25]	train-mlogloss:0.195860
# [26]	train-mlogloss:0.195842
# [27]	train-mlogloss:0.195642
# [28]	train-mlogloss:0.195612
# [29]	train-mlogloss:0.195724
# [30]	train-mlogloss:0.195744
# [31]	train-mlogloss:0.195766
# [32]	train-mlogloss:0.195646
# [33]	train-mlogloss:0.195642
# [34]	train-mlogloss:0.195677
# [35]	train-mlogloss:0.195625
# [36]	train-mlogloss:0.195716
# [37]	train-mlogloss:0.195686
# [38]	train-mlogloss:0.195634
# [39]	train-mlogloss:0.195703
# [40]	train-mlogloss:0.195610
# [41]	train-mlogloss:0.195708
# [42]	train-mlogloss:0.195780
# [43]	train-mlogloss:0.195823
# [44]	train-mlogloss:0.195811
# [45]	train-mlogloss:0.195832
# [46]	train-mlogloss:0.195871
# [47]	train-mlogloss:0.195879
# [48]	train-mlogloss:0.195915
# [49]	train-mlogloss:0.195980
# [50]	train-mlogloss:0.196024
# [51]	train-mlogloss:0.196071
# [52]	train-mlogloss:0.196096
# [53]	train-mlogloss:0.196122
# [54]	train-mlogloss:0.196157
# [55]	train-mlogloss:0.196177
# [56]	train-mlogloss:0.196156
# [57]	train-mlogloss:0.196191
# [58]	train-mlogloss:0.196258
# [59]	train-mlogloss:0.196260
# [60]	train-mlogloss:0.196303
# [61]	train-mlogloss:0.196384
# [62]	train-mlogloss:0.196402
# [63]	train-mlogloss:0.196475
# [64]	train-mlogloss:0.196529
# [65]	train-mlogloss:0.196546
# [66]	train-mlogloss:0.196519
# [67]	train-mlogloss:0.196624
# [68]	train-mlogloss:0.196641
# [69]	train-mlogloss:0.196712
# [70]	train-mlogloss:0.196694
# [71]	train-mlogloss:0.196711
# [72]	train-mlogloss:0.196693
# [73]	train-mlogloss:0.196708
# [74]	train-mlogloss:0.196769
# [75]	train-mlogloss:0.196802
# [76]	train-mlogloss:0.196809
# [77]	train-mlogloss:0.196766
# [78]	train-mlogloss:0.196806
# [79]	train-mlogloss:0.196874
# [80]	train-mlogloss:0.196946
# [81]	train-mlogloss:0.197007
# [82]	train-mlogloss:0.197120
# [83]	train-mlogloss:0.197182
# [84]	train-mlogloss:0.197219
# [85]	train-mlogloss:0.197227
# [86]	train-mlogloss:0.197239
# [87]	train-mlogloss:0.197324
# [88]	train-mlogloss:0.197378
# [89]	train-mlogloss:0.197421
# [90]	train-mlogloss:0.197493
# [91]	train-mlogloss:0.197561
# [92]	train-mlogloss:0.197574
# [93]	train-mlogloss:0.197605
# [94]	train-mlogloss:0.197600
# [95]	train-mlogloss:0.197684
# [96]	train-mlogloss:0.197734
# [97]	train-mlogloss:0.197756
# [98]	train-mlogloss:0.197776
# [99]	train-mlogloss:0.197799
# [100]	train-mlogloss:0.197799

# %%
print(xgb)
# Out:
# ##### xgb.Booster
# raw: 690.1 Kb
# call:
#   xgb.train(params = params, data = dtrain, nrounds = nrounds,
#     watchlist = watchlist, verbose = verbose, print_every_n = print_every_n,
#     early_stopping_rounds = early_stopping_rounds, maximize = maximize,
#     save_period = save_period, save_name = save_name, xgb_model = xgb_model,
#     callbacks = callbacks, objective = "multi:softmax", num_class = ..2)
# params (as set within xgb.train):
#   objective = "multi:softmax", num_class = "3", validate_parameters = "TRUE"
# xgb.attributes:
#   niter
# callbacks:
#   cb.print.evaluation(period = print_every_n)
#   cb.evaluation.log()
# # of features: 32
# niter: 100
# nfeatures : 32
# evaluation_log:
#      iter train_mlogloss
#     <num>          <num>
#         1      0.7771118
#         2      0.5937016
# ---
#        99      0.1977992
#       100      0.1977986

# %%
pred_test <- predict(xgb, test_data_encoded)

# %%
pred_test <- as.factor(pred_test)

# %%
accuracy <- mean(pred_test == test_data$class)
print(paste("Accuracy:", accuracy))
# Out:
# [1] "Accuracy: 0.809160305343511"
